# %%
#Importing in panda, a popular open-source Python library used for data manipulation and analysis.
#Other tools are imported just in case I end up using them. 

import pandas as pd
import matplotlib
import numpy as np
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline

#This is me opening the original dataset from Kaggle and storing it in a dataframe.  
#The output displays my dataset and it shows all of the column names and the first and last 5 rows only.
# At the bottom, it also tells me how many rows there are in total (5000) and rows (11).

df_csv = pd.read_csv("Sales_Data.csv")
df_csv
# Out:
#                                  Region               Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
#I prefer to make a copy of the original data file and working with that instead. 
#This code helps me to do that by saving the data from the Dataframe into this file. 

df_csv.to_csv("data_all_regions_raw.csv")

# %%
#This is me opening the my copied file of the original dataset from Kaggle and storing it in a dataframe.
#Now, I can begin to start exploring the data. 

#Once again, the output displays my dataset and it shows all of the column names and the first and last 5 rows only. At the bottom, it also tells me how many rows there are in total (5000) and rows (11).
#However, there is now 1 additional column so now I have 12 rows.

df_csv = pd.read_csv("data_all_regions_raw.csv")
df_csv
# Out:
#       Unnamed: 0                             Region               Country  \
# 0              0  Central America and the Caribbean  Antigua and Barbuda
# 1              1  Central America and the Caribbean                Panama
# 2              2                             Europe        Czech Republic
# 3              3                               Asia           North Korea
# 4              4                               Asia             Sri Lanka
# ...          ...                                ...                   ...
# 4995        4995              Australia and Oceania           New Zealand
# 4996        4996       Middle East and North Africa            Azerbaijan
# 4997        4997                               Asia               Myanmar
# 4998        4998                             Europe               Finland
# 4999        4999                 Sub-Saharan Africa              Tanzania
#
#        Item_Type Sales_Channel Order_Priority  Order_Date     Order_ID  \
# ...

# %%
df_csv.info #This provides a consice summary of my dataframe.
# Out:
# <bound method DataFrame.info of       Unnamed: 0                             Region               Country  \
# 0              0  Central America and the Caribbean  Antigua and Barbuda
# 1              1  Central America and the Caribbean                Panama
# 2              2                             Europe        Czech Republic
# 3              3                               Asia           North Korea
# 4              4                               Asia             Sri Lanka
# ...          ...                                ...                   ...
# 4995        4995              Australia and Oceania           New Zealand
# 4996        4996       Middle East and North Africa            Azerbaijan
# 4997        4997                               Asia               Myanmar
# 4998        4998                             Europe               Finland
# 4999        4999                 Sub-Saharan Africa              Tanzania
#
# ...

# %%
df_csv.columns #This displays all of the columns in my dataframe.
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Order_Date', 'Order_ID', 'Ship_Date', 'Units_Sold',
#        'Unit_SellingPrice', 'Unit_MakingCost'],
#       dtype='object')

# %%
df_csv.head(25) #This displays the first 25 rows in my dataframe.
# Out:
#                                Region                           Country  \
# 0   Central America and the Caribbean              Antigua and Barbuda
# 1   Central America and the Caribbean                            Panama
# 2                              Europe                    Czech Republic
# 3                                Asia                       North Korea
# 4                                Asia                         Sri Lanka
# 5        Middle East and North Africa                           Morocco
# 6               Australia and Oceania    Federated States of Micronesia
# 7                              Europe            Bosnia and Herzegovina
# 8        Middle East and North Africa                       Afghanistan
# 9                  Sub-Saharan Africa                          Ethiopia
# 10       Middle East and North Africa                            Turkey
# 11       Middle East and North Africa                              Oman
# ...

# %%
df_csv.tail(25) #This displays the last 25 rows in my dataframe.
# Out:
#       Unnamed: 0                        Region               Country  \
# 4975        4975         Australia and Oceania                Samoa
# 4976        4976            Sub-Saharan Africa                Zambia
# 4977        4977            Sub-Saharan Africa                 Gabon
# 4978        4978                        Europe               Belarus
# 4979        4979            Sub-Saharan Africa                  Chad
# 4980        4980                          Asia             Indonesia
# 4981        4981            Sub-Saharan Africa               Eritrea
# 4982        4982  Middle East and North Africa                  Iran
# 4983        4983                          Asia           South Korea
# 4984        4984                          Asia              Cambodia
# 4985        4985                          Asia                  Laos
# 4986        4986                          Asia             Sri Lanka
# 4987        4987                        Europe                Norway
# ...

# %%
df_csv.drop(columns=['Order_Priority'], inplace=True)

# %%
df_csv.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Date',
#        'Order_ID', 'Ship_Date', 'Units_Sold', 'Unit_SellingPrice',
#        'Unit_MakingCost'],
#       dtype='object')

# %%
df_csv['Order_Date'] = pd.to_datetime(df_csv['Order_Date'], errors='coerce', dayfirst=False)

# %%
df_csv['Ship_Date'] = pd.to_datetime(df_csv['Ship_Date'], errors='coerce', dayfirst=False)

# %%
df_csv['Order_ID'] = df_csv['Order_ID'].astype('int64')

# %%
df_csv['Units_Sold'] = df_csv['Units_Sold'].astype('int64')

# %%
df_csv['Unit_SellingPrice'] = df_csv['Unit_SellingPrice'].astype('float64')

# %%
df_csv['Unit_MakingCost'] = df_csv['Unit_MakingCost'].astype('float64')

# %%
df_csv.drop_duplicates(inplace=True)

# %%
print(df_csv.head())
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales_Channel           Order_Date   Order_ID            Ship_Date  \
# 0        Online  2013-12-20 00:00:00  957081544  2014-01-11 00:00:00
# 1       Offline                    0  301644504                    0
# 2       Offline                    0  478051030                    0
# 3       Offline  2010-05-13 00:00:00  892599952                    0
# 4       Offline  2015-07-20 00:00:00  571902596                    0
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost
# 0         552             255.28           159.42
# ...

# %%
df_csv.to_csv("data_all_regions_clean.csv")

# %%
df_csv = pd.read_csv("data_all_regions_clean.csv")
df_csv
# Out:
#       Unnamed: 0                             Region               Country  \
# 0              0  Central America and the Caribbean  Antigua and Barbuda
# 1              1  Central America and the Caribbean                Panama
# 2              2                             Europe        Czech Republic
# 3              3                               Asia           North Korea
# 4              4                               Asia             Sri Lanka
# ...          ...                                ...                   ...
# 4995        4995              Australia and Oceania           New Zealand
# 4996        4996       Middle East and North Africa            Azerbaijan
# 4997        4997                               Asia               Myanmar
# 4998        4998                             Europe               Finland
# 4999        4999                 Sub-Saharan Africa              Tanzania
#
#        Item_Type Sales_Channel           Order_Date   Order_ID  \
# ...

# %%
df_csv['Order_Date'] = pd.to_datetime(df_csv['Order_Date'])

df_csv['Order_Date'] = df_csv['Order_Date'].dt.date


print(df_csv)
# Out:
#       Unnamed: 0                             Region               Country  \
# 0              0  Central America and the Caribbean  Antigua and Barbuda
# 1              1  Central America and the Caribbean                Panama
# 2              2                             Europe        Czech Republic
# 3              3                               Asia           North Korea
# 4              4                               Asia             Sri Lanka
# ...          ...                                ...                   ...
# 4995        4995              Australia and Oceania           New Zealand
# 4996        4996       Middle East and North Africa            Azerbaijan
# 4997        4997                               Asia               Myanmar
# 4998        4998                             Europe               Finland
# 4999        4999                 Sub-Saharan Africa              Tanzania
#
#        Item_Type Sales_Channel  Order_Date   Order_ID            Ship_Date  \
# ...

# %%
df_csv.head(25)
# Out:
#     Unnamed: 0                             Region  \
# 0            0  Central America and the Caribbean
# 1            1  Central America and the Caribbean
# 2            2                             Europe
# 3            3                               Asia
# 4            4                               Asia
# 5            5       Middle East and North Africa
# 6            6              Australia and Oceania
# 7            7                             Europe
# 8            8       Middle East and North Africa
# 9            9                 Sub-Saharan Africa
# 10          10       Middle East and North Africa
# 11          11       Middle East and North Africa
# 12          12                               Asia
# 13          13  Central America and the Caribbean
# 14          14  Central America and the Caribbean
# 15          15       Middle East and North Africa
# 16          16                             Europe
# 17          17                             Europe
# ...

# %%
df_csv['Ship_Date'] = pd.to_datetime(df_csv['Ship_Date'], errors='coerce', dayfirst=False)

df_csv['Ship_Date'] = df_csv['Ship_Date'].dt.date

print(df_csv)
# Out:
#       Unnamed: 0                             Region               Country  \
# 0              0  Central America and the Caribbean  Antigua and Barbuda
# 1              1  Central America and the Caribbean                Panama
# 2              2                             Europe        Czech Republic
# 3              3                               Asia           North Korea
# 4              4                               Asia             Sri Lanka
# ...          ...                                ...                   ...
# 4995        4995              Australia and Oceania           New Zealand
# 4996        4996       Middle East and North Africa            Azerbaijan
# 4997        4997                               Asia               Myanmar
# 4998        4998                             Europe               Finland
# 4999        4999                 Sub-Saharan Africa              Tanzania
#
#        Item_Type Sales_Channel  Order_Date   Order_ID   Ship_Date  Units_Sold  \
# ...

# %%
df_csv = pd.read_csv("data_all_regions_clean.csv")
df_csv
# Out:
#       Unnamed: 0                             Region               Country  \
# 0              0  Central America and the Caribbean  Antigua and Barbuda
# 1              1  Central America and the Caribbean                Panama
# 2              2                             Europe        Czech Republic
# 3              3                               Asia           North Korea
# 4              4                               Asia             Sri Lanka
# ...          ...                                ...                   ...
# 4995        4995              Australia and Oceania           New Zealand
# 4996        4996       Middle East and North Africa            Azerbaijan
# 4997        4997                               Asia               Myanmar
# 4998        4998                             Europe               Finland
# 4999        4999                 Sub-Saharan Africa              Tanzania
#
#        Item_Type Sales_Channel           Order_Date   Order_ID  \
# ...

# %%
df_csv_sub_saharan_africa = df_csv[df_csv['Region'] == 'Sub-Saharan Africa']

print(df_csv_sub_saharan_africa)
# Out:
#       Unnamed: 0              Region   Country        Item_Type Sales_Channel  \
# 9              9  Sub-Saharan Africa  Ethiopia        Baby Food        Online
# 28            28  Sub-Saharan Africa    Guinea        Baby Food        Online
# 33            33  Sub-Saharan Africa    Malawi             Meat        Online
# 38            38  Sub-Saharan Africa     Benin    Personal Care        Online
# 45            45  Sub-Saharan Africa    Angola  Office Supplies       Offline
# ...          ...                 ...       ...              ...           ...
# 4977        4977  Sub-Saharan Africa     Gabon  Office Supplies        Online
# 4979        4979  Sub-Saharan Africa      Chad           Snacks       Offline
# 4981        4981  Sub-Saharan Africa   Eritrea                0        Online
# 4994        4994  Sub-Saharan Africa   Liberia        Cosmetics       Offline
# 4999        4999  Sub-Saharan Africa  Tanzania       Vegetables        Online
#
# ...

# %%
df_csv_sub_saharan_africa.to_csv('data_sub_saharan_africa_clean.csv', index=False)
